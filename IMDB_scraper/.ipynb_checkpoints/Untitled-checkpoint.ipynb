# %%
import pandas as pd

# %%
df = pd.read_csv("results.csv")
df = df.dropna()

# %%
df
# Out:
#                      actor                                   movie_or_tv_name
# 0             Ellen Pompeo  Station 19,Doc McStuffins,Taylor Swift: Bad Bl...
# 1              John Cappon  CSI: NY,NYPD Blue,Providence,The District,Bost...
# 2            Nora Zehetner  Boys of Summer,Spring Bloom,The Right Stuff,Fr...
# 3           Zaiver Sinnett                              Station 19,Station 19
# 5         Marika Dominczyk  Inventing Anna,Hawaii Five-0,Whiskey Cavalier,...
# 6         Brooke Blanchard                                          Say Uncle
# 7           Arlene Santana  North Star,CSI: Vegas,In the Darkness,Terror E...
# 8           Peyton Kennedy  Murdoch Mysteries,Borrasca,Selfie,What the Nig...
# 10             Geena Davis  Cowgirl's Last Ride,Ava,She-Ra and the Princes...
# 11           Jeanine Mason  Viral,Roswell, New Mexico,The Yellow Wallpaper...
# 12          Lauren Stamile  The Storied Life of A.J. Fikry,Let Us In,Rita,...
# ...

# %%
unique = df['movie_or_tv_name'].unique()

# %%
unique
# Out:
# array(["Station 19,Doc McStuffins,Taylor Swift: Bad Blood,Life of the Party,Art Heist,Friends,Nobody's Perfect,Undermind,Old School,Daredevil,Catch Me If You Can,Moonlight Mile,The Job,Strong Medicine,Eventual Wife,In the Weeds,Mambo Café,Get Real,Law & Order,8 1/2 x 11,Strangers with Candy,Coming Soon,Do You Have the Time,Deeds,Station 19,Thank God It's Thursday on ABC,Eternal Sunshine of the Spotless Mind,Moonlight Mile: A Journey to Screen,Entertainment Tonight,Good Morning America,Extra with Billy Bush,Jimmy Kimmel Live!,Tell Me with Ellen Pompeo,The 73rd Primetime Emmy Awards,Martha Gets Down and Dirty,CBS News Sunday Morning,The E! People's Choice Awards,Access Hollywood,Armchair Expert with Dax Shepard,The View,The Late Late Show with James Corden,Variety Studio: Actors on Actors,RuPaul's Drag Race All Stars,Red Table Talk,The Ellen DeGeneres Show,This Changes Everything,Live with Kelly and Ryan,The Chew,Late Night with Seth Meyers,The Insider,TV Land Icon Awards 2016,The 42nd
# ...

# %%
test = "Emma, Bradley, K"
test.split(",")
# Out:
# ['Emma', ' Bradley', ' K']

# %%
df = pd.read_csv("results.csv")
df = pd.concat([df['actor'], df['movie_or_tv_name'].str.split(', ', expand=True)], axis=1)
df
# Out:
#                      actor                                                  0  \
# 0             Ellen Pompeo  Station 19,Doc McStuffins,Taylor Swift: Bad Bl...
# 1              John Cappon  CSI: NY,NYPD Blue,Providence,The District,Bost...
# 2            Nora Zehetner  Boys of Summer,Spring Bloom,The Right Stuff,Fr...
# 3           Zaiver Sinnett                              Station 19,Station 19
# 4             Kevin Clarke                                                NaN
# 5         Marika Dominczyk  Inventing Anna,Hawaii Five-0,Whiskey Cavalier,...
# 6         Brooke Blanchard                                          Say Uncle
# 7           Arlene Santana  North Star,CSI: Vegas,In the Darkness,Terror E...
# 8           Peyton Kennedy  Murdoch Mysteries,Borrasca,Selfie,What the Nig...
# 9            Jela K. Moore                                                NaN
# 10             Geena Davis  Cowgirl's Last Ride,Ava,She-Ra and the Princes...
# ...

# %%
df = pd.read_csv("results.csv")
df = df['movie_or_tv_name'].str.split(',', expand=True)
df
# Out:
#                                 0                           1    \
# 0                        Station 19              Doc McStuffins
# 1                           CSI: NY                   NYPD Blue
# 2                    Boys of Summer                Spring Bloom
# 3                        Station 19                  Station 19
# 4                               NaN                         NaN
# 5                    Inventing Anna               Hawaii Five-0
# 6                         Say Uncle                        None
# 7                        North Star                  CSI: Vegas
# 8                 Murdoch Mysteries                    Borrasca
# 9                               NaN                         NaN
# 10              Cowgirl's Last Ride                         Ava
# 11                            Viral                     Roswell
# 12   The Storied Life of A.J. Fikry                   Let Us In
# 13                Grace and Frankie                    Batwoman
# ...

# %%
mydict = {}
for i in unique:
    name = 'Station 19'
    this = (df['movie_or_tv_name'].str.contains(name))
    count = sum(this)
    mydict[name] = count
# Out:
# {'Station 19': 3}

# %%
name = "Station 19"
check2= df['movie_or_tv_name'].str.contains(name)
check2
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 5     False
# 6     False
# 7     False
# 8     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29     True
# Name: movie_or_tv_name, dtype: bool
